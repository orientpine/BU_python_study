# %%
import pandas as pd
import numpy as np
import os
import names
from datetime import date

# %%
# 필요한 함수 선언
def ensure_dir(file_path):
    if not os.path.exists(file_path): # 야 거기 폴더 있냐? 없음 ㅇㅇ 
        os.makedirs(file_path)

# %%
dir_1 = './testdir_3'
ensure_dir(dir_1)

# %%
A = False 
B = False
if  A != True:
    print('A는 True 아니야')
# Out:
# A는 True 아니야

# %%
def makeColumns():
    sideType = ['Front_Left','Front_Right','Back_Left','Back_Right']
    sensorType = ['ACC', "Gyro", "Mag"]
    AxisType = ['X', 'Y', 'Z']
    lside = len(sideType)
    lsen = len(sensorType)
    lAxis = len(AxisType)
    col_acc = [f'{sideType[i//(lsen*lAxis)]}_{sensorType[(i//(lsen))%lsen]}_{AxisType[i%lAxis]}' for i in range(0,lsen*lAxis*lside)]
    return col_acc

# %%
makeColumns()
# Out:
# ['Front_Left_ACC_X',
#  'Front_Left_ACC_Y',
#  'Front_Left_ACC_Z',
#  'Front_Left_Gyro_X',
#  'Front_Left_Gyro_Y',
#  'Front_Left_Gyro_Z',
#  'Front_Left_Mag_X',
#  'Front_Left_Mag_Y',
#  'Front_Left_Mag_Z',
#  'Front_Right_ACC_X',
#  'Front_Right_ACC_Y',
#  'Front_Right_ACC_Z',
#  'Front_Right_Gyro_X',
#  'Front_Right_Gyro_Y',
#  'Front_Right_Gyro_Z',
#  'Front_Right_Mag_X',
#  'Front_Right_Mag_Y',
#  'Front_Right_Mag_Z',
#  'Back_Left_ACC_X',
#  'Back_Left_ACC_Y',
#  'Back_Left_ACC_Z',
#  'Back_Left_Gyro_X',
#  'Back_Left_Gyro_Y',
#  'Back_Left_Gyro_Z',
#  'Back_Left_Mag_X',
#  'Back_Left_Mag_Y',
#  'Back_Left_Mag_Z',
#  'Back_Right_ACC_X',
#  'Back_Right_ACC_Y',
#  'Back_Right_ACC_Z',
#  'Back_Right_Gyro_X',
#  'Back_Right_Gyro_Y',
#  'Back_Right_Gyro_Z',
#  'Back_Right_Mag_X',
#  'Back_Right_Mag_Y',
#  'Back_Right_Mag_Z']

# %%
sideType = ['Front_Left','Front_Right','Back_Left','Back_Right']
sensorType = ['ACC', "Gyro", "Mag"]
AxisType = ['X', 'Y', 'Z']
lside = len(sideType)
lsen = len(sensorType)
lAxis = len(AxisType)
list_col = []
for i in range(lside*lsen*lAxis):
    name_col = sideType[i//9] +'_' + sensorType[(i%9)//3] + '_' + AxisType[i%3]
    list_col.append(name_col)

# %%
sideType = ['ForeHead','RearHead',]
sensorType = ['fNir',]
AxisType = [str(i) for i in range(0,20)]
lside = len(sideType)
lsen = len(sensorType)
lAxis = len(AxisType)
list_col = []
for i in range(lside*lsen*lAxis):
    name_col = sideType[i//int(lsen*lAxis)] +'_' + sensorType[(i%(lsen*lAxis))//lAxis] + '_' + AxisType[i%lAxis]
    list_col.append(name_col)

# %%
list_col
# Out:
# ['ForeHead_fNir_0',
#  'ForeHead_fNir_1',
#  'ForeHead_fNir_2',
#  'ForeHead_fNir_3',
#  'ForeHead_fNir_4',
#  'ForeHead_fNir_5',
#  'ForeHead_fNir_6',
#  'ForeHead_fNir_7',
#  'ForeHead_fNir_8',
#  'ForeHead_fNir_9',
#  'ForeHead_fNir_10',
#  'ForeHead_fNir_11',
#  'ForeHead_fNir_12',
#  'ForeHead_fNir_13',
#  'ForeHead_fNir_14',
#  'ForeHead_fNir_15',
#  'ForeHead_fNir_16',
#  'ForeHead_fNir_17',
#  'ForeHead_fNir_18',
#  'ForeHead_fNir_19',
#  'RearHead_fNir_0',
#  'RearHead_fNir_1',
#  'RearHead_fNir_2',
#  'RearHead_fNir_3',
#  'RearHead_fNir_4',
#  'RearHead_fNir_5',
#  'RearHead_fNir_6',
#  'RearHead_fNir_7',
#  'RearHead_fNir_8',
#  'RearHead_fNir_9',
#  'RearHead_fNir_10',
#  'RearHead_fNir_11',
#  'RearHead_fNir_12',
#  'RearHead_fNir_13',
#  'RearHead_fNir_14',
#  'RearHead_fNir_15',
#  'RearHead_fNir_16',
#  'RearHead_fNir_17',
#  'RearHead_fNir_18',
#  'RearHead_fNir_19']

# %%
side = foreHEAD , backHead
sensor = fnir
axis = 0,1,3,4,,5,20
# Out:
#   Input In [28]
#     axis = 0,1,3,4,,5,20
#                    ^
# SyntaxError: invalid syntax

# %%
data_subject = np.random.rand(101, 36)
test_df = pd.DataFrame(data_subject,columns=list_col)
test_df
# Out:
#      Front_Left_ACC_X  Front_Left_ACC_Y  Front_Left_ACC_Z  Front_Left_Gyro_X  \
# 0            0.523515          0.883969          0.430091           0.250035
# 1            0.052012          0.355552          0.188655           0.771035
# 2            0.139257          0.225342          0.151727           0.979012
# 3            0.285466          0.702728          0.455170           0.845046
# 4            0.081761          0.685616          0.793606           0.185656
# ..                ...               ...               ...                ...
# 96           0.074469          0.964407          0.251912           0.785471
# 97           0.841685          0.994487          0.960204           0.653179
# 98           0.159721          0.536964          0.793742           0.938659
# 99           0.778558          0.230611          0.361032           0.597882
# 100          0.936975          0.965864          0.874347           0.692915
#
#      Front_Left_Gyro_Y  Front_Left_Gyro_Z  Front_Left_Mag_X  Front_Left_Mag_Y  \
# 0             0.279000           0.838574          0.453241          0.619882
# 1             0.489731           0.001633          0.025866          0.376562
# 2             0.041524           0.810994          0.171702          0.885512
# 3             0.151674           0.150411          0.482194          0.733605
# 4             0.727722           0.052994          0.115422          0.177438
# ..                 ...                ...               ...               ...
# 96            0.262600           0.684782          0.660014          0.574195
# 97            0.797648           0.961675          0.605885          0.154650
# 98            0.342978           0.614547          0.351243          0.816823
# 99            0.771335           0.307752          0.551806          0.205183
# 100           0.409666           0.664226          0.267815          0.633060
#
#      Front_Left_Mag_Z  Front_Right_ACC_X  ...  Back_Left_Mag_Z  \
# 0            0.365872           0.183177  ...         0.781116
# 1            0.106982           0.366684  ...         0.104570
# 2            0.936655           0.342041  ...         0.221072
# 3            0.739375           0.709518  ...         0.287391
# 4            0.271007           0.185460  ...         0.856966
# ..                ...                ...  ...              ...
# 96           0.865101           0.270804  ...         0.389641
# 97           0.731388           0.124700  ...         0.250296
# 98           0.872441           0.299771  ...         0.127451
# 99           0.175610           0.028588  ...         0.770921
# 100          0.267616           0.604692  ...         0.269540
#
#      Back_Right_ACC_X  Back_Right_ACC_Y  Back_Right_ACC_Z  Back_Right_Gyro_X  \
# 0            0.011479          0.558145          0.806088           0.515120
# 1            0.603097          0.801532          0.929911           0.618124
# 2            0.277692          0.814012          0.434776           0.684459
# 3            0.142671          0.718878          0.145538           0.737900
# 4            0.425482          0.118415          0.037055           0.700391
# ..                ...               ...               ...                ...
# 96           0.621292          0.197078          0.648962           0.198327
# 97           0.158886          0.241167          0.963090           0.644930
# 98           0.032959          0.392420          0.953218           0.891100
# 99           0.245606          0.102270          0.821388           0.599862
# 100          0.680861          0.861355          0.634994           0.908061
#
#      Back_Right_Gyro_Y  Back_Right_Gyro_Z  Back_Right_Mag_X  Back_Right_Mag_Y  \
# 0             0.980932           0.166050          0.707570          0.185455
# 1             0.217864           0.909224          0.227904          0.073027
# 2             0.370013           0.570228          0.730922          0.975408
# 3             0.367880           0.019091          0.421639          0.557276
# 4             0.985923           0.525736          0.234559          0.010143
# ..                 ...                ...               ...               ...
# 96            0.546880           0.677836          0.105014          0.556940
# 97            0.914484           0.639120          0.081989          0.860409
# 98            0.300339           0.721050          0.934066          0.206183
# 99            0.151926           0.071331          0.979510          0.941185
# 100           0.388163           0.769843          0.220482          0.238804
#
#      Back_Right_Mag_Z
# 0            0.263026
# 1            0.953100
# 2            0.659253
# 3            0.652076
# 4            0.443375
# ..                ...
# 96           0.578036
# 97           0.807226
# 98           0.818093
# 99           0.153569
# 100          0.505682
#
# [101 rows x 36 columns]

# %%
Demographic_info = ['나이, 성별, 거주지, 소득수준, 교육수준, 키, 몸무게, 인종, BMI, 가족관계, KL']

# %%
makeColumns()
# Out:
# ['Front_Left_ACC_X',
#  'Front_Left_ACC_Y',
#  'Front_Left_ACC_Z',
#  'Front_Left_Gyro_X',
#  'Front_Left_Gyro_Y',
#  'Front_Left_Gyro_Z',
#  'Front_Left_Mag_X',
#  'Front_Left_Mag_Y',
#  'Front_Left_Mag_Z',
#  'Front_Right_ACC_X',
#  'Front_Right_ACC_Y',
#  'Front_Right_ACC_Z',
#  'Front_Right_Gyro_X',
#  'Front_Right_Gyro_Y',
#  'Front_Right_Gyro_Z',
#  'Front_Right_Mag_X',
#  'Front_Right_Mag_Y',
#  'Front_Right_Mag_Z',
#  'Back_Left_ACC_X',
#  'Back_Left_ACC_Y',
#  'Back_Left_ACC_Z',
#  'Back_Left_Gyro_X',
#  'Back_Left_Gyro_Y',
#  'Back_Left_Gyro_Z',
#  'Back_Left_Mag_X',
#  'Back_Left_Mag_Y',
#  'Back_Left_Mag_Z',
#  'Back_Right_ACC_X',
#  'Back_Right_ACC_Y',
#  'Back_Right_ACC_Z',
#  'Back_Right_Gyro_X',
#  'Back_Right_Gyro_Y',
#  'Back_Right_Gyro_Z',
#  'Back_Right_Mag_X',
#  'Back_Right_Mag_Y',
#  'Back_Right_Mag_Z']

# %%
num_file = 10
data_length = 101
num_feature = 36
save_dir = './IMU_EXP'
ensure_dir(save_dir)
for i in range(0,num_file):
    # 피험자 이름 생성
    name_subject = names.get_full_name()
    # 오늘 날짜
    str_date = date.today().strftime("%B_%d_%Y")
    # 데이터 생성
    data_subject = np.random.rand(data_length, num_feature)
    # columns 생성
    list_col = makeColumns()
    # columns 별 데이터 생성 (random 생성, 0에서 1사이 데이터)
    df_subject = pd.DataFrame(data_subject, columns=list_col)
    # 각파일별 이름 저장
    df_subject.to_excel(os.path.join(save_dir,f"{str_date}_{name_subject}_IMUData.xlsx"))

# %%
save_dir = './test'
str_date = date.today().strftime("%B_%d_%Y")
name_subject = '차백동'
os.path.join(save_dir,f"{str_date}_{name_subject}_IMUData.xlsx")
# Out:
# './test\\June_02_2022_차백동_IMUData.xlsx'

# %%
date.today().strftime("%B_%d_%Y")
# Out:
# 'June_02_2022'

# %%
for i in range(0,15):
    print((i//3)%3)
# Out:
# 0
# 0
# 0
# 1
# 1
# 1
# 2
# 2
# 2
# 0
# 0
# 0
# 1
# 1
# 1

# %%
    df_subject2 = pd.DataFrame(data_subject, columns=list_col)
    df_subject3 = pd.concat([df_subject,df_subject2], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\BU\Others\computer\BU_python_study\KIM_HJ\table_generator.ipynb Cell 18' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/BU/Others/computer/BU_python_study/KIM_HJ/table_generator.ipynb#ch0000017?line=0'>1</a> df_subject2 = pd.DataFrame(data_subject, columns=list_col)
#       <a href='vscode-notebook-cell:/d%3A/BU/Others/computer/BU_python_study/KIM_HJ/table_generator.ipynb#ch0000017?line=1'>2</a> df_subject3 = pd.concat([df_subject,df_subject2], ignore_index=True)
#
# File c:\Users\HyunJoon_Kim\anaconda3\envs\bu\lib\site-packages\pandas\core\frame.py:694, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=683'>684</a>         mgr = dict_to_mgr(
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=684'>685</a>             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=685'>686</a>             # attribute "name"
#    (...)
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=690'>691</a>             typ=manager,
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=691'>692</a>         )
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=692'>693</a>     else:
# --> <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=693'>694</a>         mgr = ndarray_to_mgr(
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=694'>695</a>             data,
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=695'>696</a>             index,
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=696'>697</a>             columns,
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=697'>698</a>             dtype=dtype,
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=698'>699</a>             copy=copy,
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=699'>700</a>             typ=manager,
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=700'>701</a>         )
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=702'>703</a> # For data is list-like, or Iterable (will consume into list)
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/frame.py?line=703'>704</a> elif is_list_like(data):
#
# File c:\Users\HyunJoon_Kim\anaconda3\envs\bu\lib\site-packages\pandas\core\internals\construction.py:351, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/internals/construction.py?line=345'>346</a> # _prep_ndarray ensures that values.ndim == 2 at this point
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/internals/construction.py?line=346'>347</a> index, columns = _get_axes(
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/internals/construction.py?line=347'>348</a>     values.shape[0], values.shape[1], index=index, columns=columns
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/internals/construction.py?line=348'>349</a> )
# --> <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/internals/construction.py?line=350'>351</a> _check_values_indices_shape_match(values, index, columns)
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/internals/construction.py?line=352'>353</a> if typ == "array":
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/internals/construction.py?line=354'>355</a>     if issubclass(values.dtype.type, str):
#
# File c:\Users\HyunJoon_Kim\anaconda3\envs\bu\lib\site-packages\pandas\core\internals\construction.py:422, in _check_values_indices_shape_match(values, index, columns)
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/internals/construction.py?line=419'>420</a> passed = values.shape
#     <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/internals/construction.py?line=420'>421</a> implied = (len(index), len(columns))
# --> <a href='file:///c%3A/Users/HyunJoon_Kim/anaconda3/envs/bu/lib/site-packages/pandas/core/internals/construction.py?line=421'>422</a> raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (101, 18), indices imply (101, 36)

# %%
1 i l L I
# Out:
#   Input In [20]
#     1 i l L I
#       ^
# SyntaxError: invalid syntax

# %%
data_subject = np.random.rand(101, 3)
data_subject.shape
# Out:
# (101, 3)

# %%
X_rand = np.random.rand(101, 1)
Y_rand = np.random.rand(101, 1)
Z_rand = np.random.rand(101, 1)

# %%
data = {'X':X_rand[:,0],'Y':Y_rand[:,0]}
pd.DataFrame(data)
# Out:
#             X         Y
# 0    0.474686  0.771143
# 1    0.784626  0.226857
# 2    0.124444  0.115032
# 3    0.916379  0.593529
# 4    0.698171  0.718372
# ..        ...       ...
# 96   0.134073  0.901748
# 97   0.109819  0.970991
# 98   0.641672  0.332010
# 99   0.765409  0.677190
# 100  0.926132  0.138793
#
# [101 rows x 2 columns]

# %%
X_rand[:,0].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\BU\Others\computer\BU_python_study\KIM_HJ\table_generator.ipynb Cell 23' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/BU/Others/computer/BU_python_study/KIM_HJ/table_generator.ipynb#ch0000022?line=0'>1</a> X_rand[:,0].shape
#
# NameError: name 'X_rand' is not defined
