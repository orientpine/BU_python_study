# %%
import pandas as pd
import numpy as np
import os
from natsort import natsorted
import sklearn
import names
from datetime import date

# %%
imuFolder = r'IMU_EXP'
saveFolder = r'rms_results'
dataExt = '.xlsx'
saveDir = os.path.join(imuFolder, saveFolder)
ensureDir = (saveDir)
list_imu = natsorted([_for_in os listdir(imuFolder) if _endswith(dataExt)])
for filename in list_imu:
    data = pd..read_excel(os.path.join(imuFolder, filename), engine='openpyxl')
    print(f('ss'))

# %%
class_data = pd.read_excel('./June_02_2022_Adam Gonzalea_IMUData.xlsx')
class_data
# Out:
#      Unnamed: 0  Front_Left_ACC_X  Front_Left_ACC_Y  Front_Left_ACC_Z  \
# 0             0          0.282818          0.268268          0.974085
# 1             1          0.793266          0.954533          0.801552
# 2             2          0.544120          0.746735          0.508659
# 3             3          0.180058          0.108028          0.440121
# 4             4          0.669013          0.998867          0.188397
# ..          ...               ...               ...               ...
# 96           96          0.724918          0.005743          0.452207
# 97           97          0.307154          0.826067          0.396248
# 98           98          0.852396          0.295735          0.650752
# 99           99          0.968923          0.503570          0.101544
# 100         100          0.878034          0.425834          0.986150
#
#      Front_Left_Gyro_X  Front_Left_Gyro_Y  Front_Left_Gyro_Z  \
# 0             0.399095           0.378593           0.145781
# ...

# %%
a = class_data.columns

# %%
newdata
# Out:
#      Front_Left_ACC_X  Front_Left_ACC_Y  Front_Left_ACC_Z  Back_Right_ACC_X  \
# 0            0.282818          0.268268          0.974085          0.645850
# 1            0.793266          0.954533          0.801552          0.195059
# 2            0.544120          0.746735          0.508659          0.923754
# 3            0.180058          0.108028          0.440121          0.630940
# 4            0.669013          0.998867          0.188397          0.544678
# ..                ...               ...               ...               ...
# 96           0.724918          0.005743          0.452207          0.453312
# 97           0.307154          0.826067          0.396248          0.565885
# 98           0.852396          0.295735          0.650752          0.547310
# 99           0.968923          0.503570          0.101544          0.870505
# 100          0.878034          0.425834          0.986150          0.508127
#
#      Back_Right_ACC_Y  Back_Right_ACC_Z
# ...

# %%
        class_result=pd.DataFrame(newdata, columns=['left', 'right'])
# Out:
#      left  right
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
# ..    ...    ...
# 96    NaN    NaN
# 97    NaN    NaN
# 98    NaN    NaN
# 99    NaN    NaN
# 100   NaN    NaN
#
# [101 rows x 2 columns]

# %%
def rms(x):
    rms =
